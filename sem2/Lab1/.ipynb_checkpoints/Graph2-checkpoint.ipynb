# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-1, 1.01, 0.01)
plt.plot(x, x*x-x-6)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-1, 1.01, 0.01)
y=
plt.plot(x, y)
plt.show()
